# %% [markdown]
# ## Exploratory Data Analysis on Student Performance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
data=pd.read_csv("C:/Users/HP/Documents/Verzeo Minor/StudentsPerformance (1).csv")
data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data['race/ethnicity'].unique()
#df_data['race/ethnicity'].nunique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
data['parental level of education'].unique()
#df_data['parental level of education'].nunique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# **No missing values found**

# %% [markdown]
# ### Categorical Variable Analysis

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.countplot(x="gender", data=data, hue = 'race/ethnicity')

# %%
sns.countplot(x="gender", data=data, hue = 'parental level of education')

# %%
sns.countplot(x="gender", data=data, hue = 'test preparation course')

# %%
sns.countplot(x="gender", data=data, hue = 'lunch')

# %%
sns.countplot(x="race/ethnicity", data=data, hue = 'test preparation course')

# %%
sns.countplot(x="race/ethnicity", data=data, hue = 'parental level of education')

# %%
sns.countplot(x="race/ethnicity", data=data, hue = 'lunch')

# %%
sns.countplot(x="lunch", data=data, hue = 'test preparation course')

# %% [markdown]
# ### Numerical Attributes Analysis

# %%
data['math score'].median()
# Out:
# 66.0

# %%
sns.boxplot(x='math score',data=data)

# %%
Q1 = data['math score'].quantile(0.25)
print(Q1)
Q3 = data['math score'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 57.0
# 77.0
# 20.0
# 27.0
# 107.0

# %%
sns.distplot(data['math score'])

# %% [markdown]
# **Math Score has Normal Distribution**

# %%
data['reading score'].median()
# Out:
# 70.0

# %%
sns.boxplot(x='reading score',data=data)

# %%
Q1 = data['reading score'].quantile(0.25)
print(Q1)
Q3 = data['reading score'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 59.0
# 79.0
# 20.0
# 29.0
# 109.0

# %%
sns.distplot(data['reading score'])

# %% [markdown]
# **Reading Score has Normal Distribution**

# %%
data['writing score'].median()
# Out:
# 69.0

# %%
sns.boxplot(x='writing score',data=data)

# %%
Q1 = data['writing score'].quantile(0.25)
print(Q1)
Q3 = data['writing score'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 57.75
# 79.0
# 21.25
# 25.875
# 110.875

# %%
sns.distplot(data['writing score'])

# %% [markdown]
# **Writing Score Normal Distribution**

# %%
sns.kdeplot(data['math score'],shade=True)
sns.kdeplot(data['reading score'],shade=True)
sns.kdeplot(data['writing score'],shade=True)

# %%
data['average']=(data['math score']+data['reading score']+data['writing score'])/3

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    average
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
data['average'].median()
# Out:
# 68.33333333333333

# %%
sns.boxplot(x='average',data=data)

# %%
sns.distplot(data['average'])

# %% [raw]
# ##Average Score has Normal Distribution

# %%
sns.jointplot(x="math score", y="writing score", data=data)

# %% [markdown]
# ***If a student scores good in Math he/she also scores good in Writing and vice-versa***

# %%
sns.jointplot(x="math score", y="reading score", data=data)

# %% [markdown]
# ***If a student scores good in Math he/she also scores good in Reading and vice-versa***

# %%
sns.jointplot(x="writing score", y="reading score", data=data)

# %% [markdown]
# ***If a student scores good in Writing he/she also scores good in Reading and vice-versa***

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#                math score  reading score  writing score   average
# math score       1.000000       0.817580       0.802642  0.918746
# reading score    0.817580       1.000000       0.954598  0.970331
# writing score    0.802642       0.954598       1.000000  0.965667
# average          0.918746       0.970331       0.965667  1.000000

# %% [markdown]
# ***All Numerical Attributes have positive correlation***

# %%
sns.heatmap(data.corr())

# %%
#gender	race/ethnicity	parental level of education	lunch	test preparation course	math score	reading score	writing score
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.barplot(data['gender'],data['math score'])

plt.subplot(1,3,2)
sns.barplot(data['gender'],data['reading score'])

plt.subplot(1,3,3)
sns.barplot(data['gender'],data['writing score'])

# %% [markdown]
# ***Average Score of Male and Female Students Subject wise***
#
#    -***Math :     Male>Female***
#
#    -***Reading:   Male<Female***
#
#    -***Writing:   Male<Female***

# %%
sns.barplot(data['gender'],data['average'])

# %% [markdown]
# *Average Score in all subjects- Male<Female*

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.stripplot(x="gender",y='math score',data=data)

plt.subplot(1,3,2)
sns.stripplot(x="gender",y='reading score',data=data)

plt.subplot(1,3,3)
sns.stripplot(x="gender",y='writing score',data=data)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.boxplot(x=data['gender'],y=data['math score'])

plt.subplot(1,3,2)
sns.boxplot(x=data['gender'],y=data['reading score'])

plt.subplot(1,3,3)
sns.boxplot(x=data['gender'],y=data['writing score'])

# %% [markdown]
# ***Median Score of Male and Female Students Subject wise***
#
# -***Math : Male>Female***
#
# -***Reading: Male<Female***
#
# -***Writing: Male<Female***

# %%
print('Median score of male in Math:',data.loc[data['gender']=='male', 'math score'].median(),sep=" ")
print('Median score of female in Math:',data.loc[data['gender']=='female', 'math score'].median(),sep=" ")
print('Median score of male in Reading:',data.loc[data['gender']=='male', 'reading score'].median(),sep=" ")
print('Median score of female in Reading:',data.loc[data['gender']=='female', 'reading score'].median(),sep=" ")
print('Median score of male in Writing:',data.loc[data['gender']=='male', 'writing score'].median(),sep=" ")
print('Median score of female in Writing:',data.loc[data['gender']=='female', 'writing score'].median(),sep=" ")
#median = data.loc[data['gender']=='female', 'math score'].median()
#median
# Out:
# Median score of male in Math: 69.0
# Median score of female in Math: 65.0
# Median score of male in Reading: 66.0
# Median score of female in Reading: 73.0
# Median score of male in Writing: 64.0
# Median score of female in Writing: 74.0

# %%
sns.boxplot(x=data['gender'],y=data['average'])

# %%
#race/ethnicity
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.barplot(data['race/ethnicity'],data['math score'])

plt.subplot(1,3,2)
sns.barplot(data['race/ethnicity'],data['reading score'])

plt.subplot(1,3,3)
sns.barplot(data['race/ethnicity'],data['writing score'])

# %% [markdown]
# ***Students belonging to group E tend to score higher in every subject***
#
# ***Students belonging to group A tend to score lower in every subject***

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.stripplot(x="race/ethnicity",y='math score',data=data)

plt.subplot(1,3,2)
sns.stripplot(x="race/ethnicity",y='reading score',data=data)

plt.subplot(1,3,3)
sns.stripplot(x="race/ethnicity",y='writing score',data=data)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.boxplot(x=data['race/ethnicity'],y=data['math score'])

plt.subplot(1,3,2)
sns.boxplot(x=data['race/ethnicity'],y=data['reading score'])

plt.subplot(1,3,3)
sns.boxplot(x=data['race/ethnicity'],y=data['writing score'])

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
day_wise=sns.barplot(x=data['parental level of education'],y=data['math score'])
plt.title("math score based on level of education of parents")
xticks(rotation=90)
plt.ylabel('average math score', fontsize=12)
plt.xlabel('parents level of education', fontsize=12)

plt.subplot(1,3,2)
day_wise=sns.barplot(x=data['parental level of education'],y=data['reading score'])
plt.title("math score based on level of education of parents")
xticks(rotation=90)
plt.ylabel('average math score', fontsize=12)
plt.xlabel('parents level of education', fontsize=12)

plt.subplot(1,3,3)
day_wise=sns.barplot(x=data['parental level of education'],y=data['writing score'])
plt.title("writing score based on level of education of parents")
xticks(rotation=90)
plt.ylabel('average writing score', fontsize=12)
plt.xlabel('parents level of education', fontsize=12)
# Out:
# Text(0.5, 0, 'parents level of education')

# %% [markdown]
# ***Students with Parents having Master's Degree tend to score higher in every subject***
#
# ***Students with Parents having High School tend to score lower in every subject***
#
# ***As the level of Education of Parents Increases Students scores also improves***

# %%
day_wise=sns.barplot(x=data['parental level of education'],y=data['average'])
plt.title("writing score based on level of education of parents")
xticks(rotation=90)
plt.ylabel('average writing score', fontsize=12)
plt.xlabel('parents level of education', fontsize=12)
# Out:
# Text(0.5, 0, 'parents level of education')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.stripplot(x="parental level of education",y='math score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.stripplot(x="parental level of education",y='reading score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.stripplot(x="parental level of education",y='writing score',data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.barplot(data['lunch'],data['math score'])

plt.subplot(1,3,2)
sns.barplot(data['lunch'],data['reading score'])

plt.subplot(1,3,3)
sns.barplot(data['lunch'],data['writing score'])

# %% [markdown]
# ***Students having standard lunch tend to score higher in every subject***
#
# ***Students having free/reduced lunch tend to score lower in every subject***

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.boxplot(x=data['lunch'],y=data['math score'])

plt.subplot(1,3,2)
sns.boxplot(x=data['lunch'],y=data['reading score'])

plt.subplot(1,3,3)
sns.boxplot(x=data['lunch'],y=data['writing score'])

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.stripplot(x="lunch",y='math score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.stripplot(x="lunch",y='reading score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.stripplot(x="lunch",y='writing score',data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
#sns.lmplot('reading score', 'math score', 
#           data=data,hue='gender')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.barplot(data['test preparation course'],data['math score'])

plt.subplot(1,3,2)
sns.barplot(data['test preparation course'],data['reading score'])

plt.subplot(1,3,3)
sns.barplot(data['test preparation course'],data['writing score'])

# %% [markdown]
# ***Students completing test preparation course tend to score higher in every subject***
#
# ***Students not completing test preparation course tend to score lower in every subject***

# %%
sns.barplot(data['test preparation course'],data['average'])

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.boxplot(x=data['test preparation course'],y=data['math score'])

plt.subplot(1,3,2)
sns.boxplot(x=data['test preparation course'],y=data['reading score'])

plt.subplot(1,3,3)
sns.boxplot(x=data['test preparation course'],y=data['writing score'])

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.stripplot(x="test preparation course",y='math score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.stripplot(x="test preparation course",y='reading score',data=data)
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.stripplot(x="test preparation course",y='writing score',data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
sns.lmplot('reading score', 'math score',data=data,hue='gender', markers=["o", "x"], palette="Set1")
#sns.lmplot('reading score', 'math score', 
#           data=data,hue='gender')

# %% [markdown]
# ***Generally every Male student score better in Math then Female Student***
#
# ***Generally every Female student score better in Reading then Male Student***

# %%
sns.lmplot('writing score', 'math score',data=data,hue='gender', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Male student score better in Math then Female Student***
#
# ***Generally every Female student score better in Writing then Male Student***

# %%
sns.lmplot('reading score', 'writing score',data=data,hue='gender', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Male and Female student scores almost same score in both Reading and Writing but some Female students scores much higher than other students***

# %%
sns.lmplot('reading score', 'math score',data=data,hue='test preparation course', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Student completing test preparation course who score better in Math also Scores better in Reading than Student not completing test preparation course***

# %%
sns.lmplot('writing score', 'math score',data=data,hue='test preparation course', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Student completing test preparation course who score better in Math also Scores better in Reading than Student not completing test preparation course***

# %%
sns.lmplot('reading score', 'writing score',data=data,hue='test preparation course', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Student completing test preparation course who score better in Writing,scores marginally lower in Reading than Student not completing test preparation course***

# %%
sns.lmplot('reading score', 'math score',data=data,hue='lunch', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Student having Standard lunch who score better in Math,also scores higher in Reading than Student having Free/Reduce lunch***

# %%
sns.lmplot('writing score', 'math score',data=data,hue='lunch', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Generally every Student having Standard lunch who score better in Math,also scores higher in Writing than Student having Free/Reduce lunch***

# %%
sns.lmplot('reading score', 'writing score',data=data,hue='lunch', markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***Every Student having Standard lunch and Student having Free/Reduce lunch scores almost equal in both subjects.But former has slightly higher score***

# %%
sns.lmplot('math score', 'writing score', 
           data=data,
           hue='gender',
           col='lunch',
           row='test preparation course',markers=["o", "x"], palette="Set1")

# %%
sns.lmplot('math score', 'reading score', 
           data=data,
           hue='gender',
           col='lunch',
           row='test preparation course',markers=["o", "x"], palette="Set1")

# %%
sns.lmplot('writing score', 'reading score', 
           data=data,
           hue='gender',
           col='lunch',
           row='test preparation course',markers=["o", "x"], palette="Set1")

# %% [markdown]
# ***-Female student having standard lunch and completing test course preparation tend to score higher in Reading and Writing***
#
# ***-Male student having standard lunch and completing test course preparation tend to score higher in Math***

# %%
data['math pass']=np.where(data['math score'] < 35,'F','P')

# %%
data['writing pass']=np.where(data['writing score'] < 35,'F','P')

# %%
data['reading pass']=np.where(data['reading score'] < 35,'F','P')

# %% [markdown]
# ***Making Passing Marks as 35***

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#      average math pass writing pass reading pass
# 0  72.666667         P            P            P
# 1  82.333333         P            P            P
# ...

# %%
data['math pass'].value_counts()
# Out:
# P    978
# F     22
# Name: math pass, dtype: int64

# %%
data['writing pass'].value_counts()
# Out:
# P    983
# F     17
# Name: writing pass, dtype: int64

# %%
data['reading pass'].value_counts()
# Out:
# P    985
# F     15
# Name: reading pass, dtype: int64

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x="gender", data=data, hue = 'math pass')

plt.subplot(1,3,2)
sns.countplot(x="gender", data=data, hue = 'writing pass')

plt.subplot(1,3,3)
sns.countplot(x="gender", data=data, hue = 'reading pass')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x="race/ethnicity", data=data, hue = 'math pass')

plt.subplot(1,3,2)
sns.countplot(x="race/ethnicity", data=data, hue = 'writing pass')

plt.subplot(1,3,3)
sns.countplot(x="race/ethnicity", data=data, hue = 'reading pass')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x="parental level of education", data=data, hue = 'math pass')
plt.xticks(rotation=90)

plt.subplot(1,3,2)
sns.countplot(x="parental level of education", data=data, hue = 'writing pass')
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sns.countplot(x="parental level of education", data=data, hue = 'reading pass')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x="lunch", data=data, hue = 'math pass')

plt.subplot(1,3,2)
sns.countplot(x="lunch", data=data, hue = 'writing pass')

plt.subplot(1,3,3)
sns.countplot(x="lunch", data=data, hue = 'reading pass')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.countplot(x="test preparation course", data=data, hue = 'math pass')

plt.subplot(1,3,2)
sns.countplot(x="test preparation course", data=data, hue = 'writing pass')

plt.subplot(1,3,3)
sns.countplot(x="test preparation course", data=data, hue = 'reading pass')

# %% [markdown]
# ***Passing rate of student belonging to following categories are better:***
#
# ***Gender-Male(In Math) Female(Reading,Writing)***
#
# ***Race/ethnicity-Group E***
#
# ***Parental Level Education-Masters Degree***
#
# ***Test Course Preparation-Completed***
#
# ***Lunch-Standard***
#
# ***Math and Writing subject seems to have more failure rate than Reading.Generally all category students perform similar in Reading***
